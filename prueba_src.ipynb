# %%
import src

# %%
url = f'https://www.bde.es/app/sif/documentosAsociaciones/periodos/202309/6602/6602_202309.xls'
output = src.pnl_all(url)
output
# Out:
#                                      Importe en euros   BBVA  Santander  \
# 0                                 MARGEN DE INTERESES  17843      32139
# 1                                    Comisiones Netas   4594       9222
# 2               Resultados de operaciones financieras   1430       1969
# 3                             Ingresos por Dividendos     75        474
# 4    Resultado de entidades valoradas por el métod...     20        462
# 5                     Otros resultados de explotación  -1859      -1395
# 6                                        MARGEN BRUTO  22104      42872
# 7                               Gastos de Explotación  -9241     -18961
# 8                                - Gastos de Personal  -4837     -10080
# 9                    - Otros Gastos de Administración  -3350      -6476
# 10                                      - Amotización  -1054      -2405
# 11                                        MARGEN NETO  12863      23911
# 12   Deterioro de activos financieros no valorados...  -3203      -9477
# 13             Provisiones o reversión de provisiones   -210      -1989
# 14                                   Otros Resultados     37         93
# 15                      RESULTADOS ANTES DE IMPUESTOS   9487      12538
# 16                          Impuestos sobre Beneficio  -3204      -3552
# 17                            RESULTADO DEL EJERCICIO   6283       8985
# 18                                       Minoritarios   -322       -842
# 19                                RESULTADO ATRIBUIDO   5961       8143
#
#     CaixaBank  Sabadell  Bankinter
# 0        7364      3512       1639
# 1        2741      1047        459
# 2         215        64         43
# 3         145         7         14
# 4         246        88         25
# 5         -21      -270       -175
# 6       10689      4448       2005
# 7       -4374     -2231       -700
# 8       -2641     -1093       -390
# 9       -1159      -745       -248
# 10       -575      -393        -62
# 11       6315      2217       1305
# 12       -706      -630       -226
# 13       -227        -4        -64
# 14        -88       -78        -11
# 15       5294      1504       1004
# 16      -1635      -475       -319
# 17       3661      1029        685
# 18         -2        -1          0
# 19       3659      1028        685

# %%
import pandas as pd
import streamlit as st

columns_to_keep = [col for col in output.columns if col != 'Importe en euros']
ratio_row = abs(output.iloc[7][columns_to_keep] / output.iloc[6][columns_to_keep])
ratio_row['Importe en euros'] = 'Ratio de Eficiencia'
output2 = output.append(ratio_row, ignore_index=True)
output2 = output2[output2['Importe en euros'] == 'Ratio de Eficiencia']
output2[columns_to_keep] = output2[columns_to_keep].round(3)*100
st.dataframe(output2),
            height=35*len(output2)+38,
            width = 700,
            hide_index=True)
# Out:
# C:\Users\E056118\AppData\Local\Temp\ipykernel_13976\1193055063.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output2 = output.append(ratio_row, ignore_index=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 10
#       8 output2 = output2[output2['Importe en euros'] == 'Ratio de Eficiencia']
#       9 output2[columns_to_keep] = output2[columns_to_keep].round(3)*100
# ---> 10 st.dataframe(output2.style.applymap(lambda _: "background-color: #2DCCCD; color: white; font-weight: bold", subset=([0], slice(None))),
#      11             height=35*len(output2)+38,
#      12             width = 700,
#      13             hide_index=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\streamlit\runtime\metrics_util.py:397, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     395         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     396 try:
# --> 397     result = non_optional_func(*args, **kwargs)
#     398 except RerunException as ex:
#     399     # Duplicated from below, because static analysis tools get confused
#     400     # by deferring the rethrow.
#     401     if tracking_activated and command_telemetry:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\streamlit\elements\arrow.py:219, in ArrowMixin.dataframe(self, data, width, height, use_container_width, hide_index, column_order, column_config)
#     217     delta_path = self.dg._get_delta_path_str()
#     218     default_uuid = str(hash(delta_path))
# --> 219     marshall_styler(proto, data, default_uuid)
#     221 # Convert the input data into a pandas.DataFrame
#     222 data_df = type_util.convert_anything_to_df(data, ensure_copy=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\streamlit\elements\lib\pandas_styler_utils.py:57, in marshall_styler(proto, styler, default_uuid)
#      53 _marshall_uuid(proto, styler, default_uuid)
#      55 # We're using protected members of pandas.Styler to get styles,
#      56 # which is not ideal and could break if the interface changes.
# ---> 57 styler._compute()
#      59 pandas_styles = styler._translate(False, False)
#      61 _marshall_caption(proto, styler)
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\io\formats\style_render.py:258, in StylerRenderer._compute(self)
#     256 r = self
#     257 for func, args, kwargs in self._todo:
# --> 258     r = func(self)(*args, **kwargs)
#     259 return r
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\io\formats\style.py:2000, in Styler._applymap(self, func, subset, **kwargs)
#    1998     subset = IndexSlice[:]
#    1999 subset = non_reducing_slice(subset)
# -> 2000 result = self.data.loc[subset].applymap(func)
#    2001 self._update_ctx(result)
#    2002 return self
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:924, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     921 if com.is_null_slice(key):
#     922     continue
# --> 924 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     925 # We should never have retval.ndim < self.ndim, as that should
#     926 #  be handled by the _getitem_lowerdim call above.
#     927 assert retval.ndim == self.ndim
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\E056118\.conda\envs\newsletter\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([0], dtype='int64')] are in the [index]"
