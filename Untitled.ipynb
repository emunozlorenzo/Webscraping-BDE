# %%
import yfinance as yf
import pandas as pd

# %%
dict_ibex35 = {'BBVA':'BBVA.MC','Santander':'SAN.MC','Sabadell':'SAB.MC','CaixaBank':'CABK.MC','Bankinter':'BKT.MC'}
df = pd.DataFrame()
for k,v in dict_ibex35.items():
    comp = yf.Ticker(v)
    hist = comp.history(period='1d')
    hist.reset_index(inplace=True)
    hist['Bank'] = k
    df = pd.concat([df, hist], ignore_index=True, sort=False)
    
df.drop(columns=['Date','Dividends','Stock Splits'], inplace=True)
cols = df.columns
df = df[['Bank']+cols[0:4].to_list()]

# %%
df.style.set_table_styles(
   [{
       'selector': 'th',
       'props': [('background-color', '#add8e6')]
   }])
# Out:
# <style type="text/css">
# #T_21ead th {
#   background-color: #add8e6;
# }
# </style>
# <table id="T_21ead">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ead_level0_col0" class="col_heading level0 col0" >Bank</th>
#       <th id="T_21ead_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_21ead_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_21ead_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_21ead_level0_col4" class="col_heading level0 col4" >Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21ead_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21ead_row0_col0" class="data row0 col0" >BBVA</td>
#       <td id="T_21ead_row0_col1" class="data row0 col1" >8.330000</td>
#       <td id="T_21ead_row0_col2" class="data row0 col2" >8.458000</td>
#       <td id="T_21ead_row0_col3" class="data row0 col3" >8.324000</td>
#       <td id="T_21ead_row0_col4" class="data row0 col4" >8.458000</td>
#     </tr>
#     <tr>
#       <th id="T_21ead_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21ead_row1_col0" class="data row1 col0" >Santander</td>
#       <td id="T_21ead_row1_col1" class="data row1 col1" >3.740500</td>
#       <td id="T_21ead_row1_col2" class="data row1 col2" >3.761000</td>
#       <td id="T_21ead_row1_col3" class="data row1 col3" >3.731500</td>
#       <td id="T_21ead_row1_col4" class="data row1 col4" >3.754000</td>
#     </tr>
#     <tr>
#       <th id="T_21ead_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21ead_row2_col0" class="data row2 col0" >Sabadell</td>
#       <td id="T_21ead_row2_col1" class="data row2 col1" >1.323500</td>
#       <td id="T_21ead_row2_col2" class="data row2 col2" >1.324500</td>
#       <td id="T_21ead_row2_col3" class="data row2 col3" >1.310000</td>
#       <td id="T_21ead_row2_col4" class="data row2 col4" >1.317000</td>
#     </tr>
#     <tr>
#       <th id="T_21ead_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21ead_row3_col0" class="data row3 col0" >CaixaBank</td>
#       <td id="T_21ead_row3_col1" class="data row3 col1" >4.126000</td>
#       <td id="T_21ead_row3_col2" class="data row3 col2" >4.156000</td>
#       <td id="T_21ead_row3_col3" class="data row3 col3" >4.120000</td>
#       <td id="T_21ead_row3_col4" class="data row3 col4" >4.148000</td>
#     </tr>
#     <tr>
#       <th id="T_21ead_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21ead_row4_col0" class="data row4 col0" >Bankinter</td>
#       <td id="T_21ead_row4_col1" class="data row4 col1" >6.430000</td>
#       <td id="T_21ead_row4_col2" class="data row4 col2" >6.440000</td>
#       <td id="T_21ead_row4_col3" class="data row4 col3" >6.394000</td>
#       <td id="T_21ead_row4_col4" class="data row4 col4" >6.406000</td>
#     </tr>
#   </tbody>
# </table>

# %%
comp = yf.Ticker('BBVA.MC')

# %%
((comp.dividends[-1]+comp.dividends[-2])/8.47)*100
# Out:
# 5.548996458087366

# %%
comp.info['dividendRate']/comp.history(period='1d')['Close'][0]
# Out:
# 0.05558183322677429

# %%
cols[0:4].to_list()
# Out:
# ['Open', 'High', 'Low', 'Close']

# %%
comp = yf.Ticker('BBVA.MC')
hist = comp.history(period='1d')
hist.reset_index()
hist['Bank'] = '
# Out:
#                        Date  Open   High    Low  Close    Volume  Dividends  \
# 0 2023-11-22 00:00:00+01:00   8.3  8.386  8.298  8.372  11327942        0.0
#
#    Stock Splits
# 0           0.0

# %%
comp = yf.Ticker('BBVA.MC')
hist = comp.history(period='5d')
hist
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2023-11-16 00:00:00+01:00  8.222  8.260  8.166  8.168  10857034        0.0
# 2023-11-17 00:00:00+01:00  8.200  8.302  8.192  8.284  24591636        0.0
# 2023-11-20 00:00:00+01:00  8.280  8.332  8.270  8.286  12598889        0.0
# 2023-11-21 00:00:00+01:00  8.260  8.336  8.230  8.296  10608500        0.0
# 2023-11-22 00:00:00+01:00  8.300  8.386  8.298  8.372  11327942        0.0
#
#                            Stock Splits
# Date
# 2023-11-16 00:00:00+01:00           0.0
# 2023-11-17 00:00:00+01:00           0.0
# 2023-11-20 00:00:00+01:00           0.0
# 2023-11-21 00:00:00+01:00           0.0
# 2023-11-22 00:00:00+01:00           0.0

# %%
comp = yf.Ticker('BBVA.MC')
hist = comp.history(period='1mo')
hist
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2023-10-23 00:00:00+02:00  7.522  7.544  7.430  7.522   9429359        0.0
# 2023-10-24 00:00:00+02:00  7.522  7.528  7.360  7.392  19719702        0.0
# 2023-10-25 00:00:00+02:00  7.370  7.470  7.322  7.430  16909629        0.0
# 2023-10-26 00:00:00+02:00  7.378  7.474  7.306  7.462  15551700        0.0
# 2023-10-27 00:00:00+02:00  7.516  7.624  7.414  7.442  11428201        0.0
# 2023-10-30 00:00:00+01:00  7.466  7.536  7.406  7.504  11384617        0.0
